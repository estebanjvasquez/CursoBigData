# %%
# VARIABLES
# CREAR VARIABLES
entero = 2
decimal = 2.6
texto = "Hola"
verdadero = True
falso = False

# %%
# USAR VARIABLES
print(decimal)
texto
# Out:
# 2.6
# 'Hola'

# %%
str(2.6)
int()
float()
bool()
# Out:
# '2.6'

# %%
# ESTRUCTURAS DE DATOS
# LISTAS
lista = [1,2,3,4,"Hola",True]
lista[0]
# Out:
# 1

# %%
lista.append("Luis")
lista
# Out:
# [1, 2, 3, 4, 'Hola', True, 'Luis']

# %%
lista.insert(0,"José")
lista
# Out:
# ['José', 1, 2, 3, 4, 'Hola', True, 'Luis']

# %%
# Corchetes []
# Paréntesis ()
# Llaves {}

# %%
# CONJUNTOS (set)
conjuntos = {1,2,3,4,1,"Hola",True}
conjuntos
# Out:
# {1, 2, 3, 4, 'Hola'}

# %%
# TUPLAS
tuplas = (1,2,3,4)
tuplas
# Out:
# (1, 2, 3, 4)

# %%
# DICCIONARIO
diccionario = {0:1,1:2,2:3,3:4,4:"Hola",5:True,"Luis":56}
diccionario["Luis"]
# Out:
# 56

# %%
# OPERADOR DE ASIGNACIÓN
# nombre_variable = valor
# OPERADORES ARITMETICOS
6 + 5
9 - 5
9 * 2
9 / 2
9 // 2
9 ** 3
8 % 2

# %%
# Jerarquia de las operaciones
# ()
# * y /
# + y -
(2 + 5) * 3
# Out:
# 21

# %%
str1 = 'Me gusta Python'
str1[2]
# Out:
# ' '

# %%
str1 = ['Me', 'gusta', 'Python']
str1[2]
# Out:
# 'Python'

# %%
# CONDICIONALES
# OPERADORES DE COMPARACION
8 > 5
8 >= 5
8 < 5
"2" == 2
2 != "Hola"
# Out:
# True

# %%
if 8 > 5:
  print("Cierto, ocho es mayor que cinco")
else:
  print("Falso")
# Out:
# Cierto, ocho es mayor que cinco
